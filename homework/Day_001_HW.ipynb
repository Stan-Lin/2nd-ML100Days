# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
HW1: 
    1.google play store之 Dataset. 瞭解人們的需求。 現在人生活圍繞在手機，藉由手機的app來存取各種服務。由app 分類、使用者評論來，多樣化的資訊來預測哪些APP 最容易被使用。
    2.Lavanya Gupta. 分析web的資料擷取下來

    3.表格
    4.預測設計哪種APP能吸引使用者付費購買。 將1/3資料當作測試組，使用MSE 將測試資料算出驗證
# Out:
#   File "<ipython-input-17-5294d7936ead>", line 1
#     HW1:
#          ^
# SyntaxError: invalid syntax

# %%
HW2:
    1.什麼東西會影響業績 ex:天氣,節日,車子裝飾,車款...etc
    2.透過公司的叫車系統，將過去的資料，日期、各車的編號加以標示出，並加入天氣...等額外資訊
    3.表格
    4.將各個變素加入權重之後，使用MSE 與實際結果做對照看哪個載客量最大 (業績最好

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """
    mse=MSE = sum( abs(y-yp)*abs(y-yp))/len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 208.486
# The Mean absolute error is 11.454
